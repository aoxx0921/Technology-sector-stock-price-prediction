# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('raw_data.csv')
# Out:
# /Users/mani/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   symbol        Date        Open        High         Low       Close  \
# 0   BIDU  2014-01-16  171.300003  174.570007  169.750000  173.000000
# 1   QCOM  2014-01-16   74.470001   74.879997   74.010002   74.720001
# 2    IBM  2014-01-16  187.529999  188.990005  186.800003  188.759995
# 3   CSCO  2014-01-16   22.850000   22.910000   22.629999   22.780001
# 4   ADBE  2014-01-16   61.590000   61.980000   61.259998   61.630001
#
#     Adj.Close    Volume       revenue  gross_profit    ...           MFI  \
# 0  173.000000   2975000  9.522913e+09  5.866424e+09    ...     42.611467
# 1   65.324356  10263200  6.622000e+09  3.916000e+09    ...     39.304866
# 2  163.875153   4770300  2.738500e+10  1.062700e+10    ...     45.818767
# 3   19.831251  38918100  1.208500e+10  7.407000e+09    ...     40.648559
# 4   61.630001   3747800  1.000120e+09  8.516110e+08    ...     43.238445
#
#       Volat    CMO.Ad     CMO.Vo     RunMean       RunSD          GMMA  \
# ...

# %%
df.gross_profit
# Out:
# 0        5.866424e+09
# 1        3.916000e+09
# 2        1.062700e+10
# 3        7.407000e+09
# 4        8.516110e+08
# 5        6.836390e+08
# 6        1.640000e+09
# 7        7.613000e+09
# 8        1.895000e+09
# 9        9.452000e+09
# 10       9.423830e+08
# 11       8.611878e+09
# 12       7.333000e+09
# 13       6.040000e+08
# 14       1.492800e+10
# 15       8.206000e+09
# 16       6.915000e+09
# 17       2.974100e+10
# 18       7.730000e+09
# 19       4.052000e+09
# 20       9.344670e+08
# 21       1.638000e+09
# 22       1.211000e+10
# 23       1.737024e+09
# 24       1.626000e+10
# 25       1.820045e+09
# 26       1.150000e+09
# 27       3.405000e+09
# 28       3.391200e+10
# 29       2.440000e+09
#              ...
# 18030    8.078470e+08
# 18031    9.458000e+09
# 18032    7.006000e+09
# 18033    4.066000e+09
# 18034    1.473500e+10
# 18035    7.532000e+09
# 18036    8.206000e+09
# 18037    1.881000e+09
# 18038    1.050444e+09
# 18039    6.760000e+08
# ...

# %%
df.cash_from_operation= pd.to_numeric(df.cash_from_operation)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "t"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-908d1edadc8a> in <module>()
# ----> 1 df.cash_from_operation= pd.to_numeric(df.cash_from_operation)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# ...

# %%
df = df.drop([789])

# %%
df.iloc[789,:]
# Out:
# symbol                                 ADBE
# Date                             2018-01-29
# Open                                 200.11
# High                                 200.86
# Low                                  197.87
# Close                                198.23
# Adj.Close                            198.23
# Volume                              1939000
# revenue                         2.07895e+09
# gross_profit                    1.82004e+09
# net_income                      5.83076e+08
# cash_from_operation               989601000
# basic_earning_per_share                1.18
# free_cash_flow                  1.04756e+09
# market_capital                  9.74456e+10
# enterprise_value                   1.01e+11
# VWAP_volume                         1488985
# VWAP_bid_volume_percentage          48.3109
# VWAP_ask_volume_percentage          51.6891
# px_ask                               198.23
# px_bid                               198.19
# ...

# %%
df.cash_from_operation= pd.to_numeric(df.cash_from_operation)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18059 entries, 0 to 18059
# Data columns (total 51 columns):
# symbol                          18059 non-null object
# Date                            18059 non-null object
# Open                            18059 non-null float64
# High                            18059 non-null float64
# Low                             18059 non-null float64
# Close                           18059 non-null float64
# Adj.Close                       18059 non-null float64
# Volume                          18059 non-null int64
# revenue                         18059 non-null float64
# gross_profit                    18059 non-null float64
# net_income                      18059 non-null float64
# cash_from_operation             18059 non-null float64
# basic_earning_per_share         18059 non-null float64
# free_cash_flow                  18059 non-null float64
# market_capital                  18059 non-null float64
# ...

# %%
df.to_csv('raw_data.csv',index=False)
